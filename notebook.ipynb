# %% [markdown]
# ## Museum Exhibition Data Validation
# <p>You are working with a local museum. The museum is about to launch a new interactive application on Roman emperors and your job is to prepare the data that it will display.</p>
# <p>The museum’s database has a table, named <code>emperors</code>, with basic information on all emperors who ruled from 1 AD onwards. You will need to clean the data before the app can launch.</p>
# <p>Your query will need to return a table that contains the following columns (with the given alias) and meets the specified requirements. You will use the data contained in the <code>emperors</code> table.</p>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">Requirements</th>
# <th style="text-align:left;">Data Type</th>
# <th style="text-align:left;">Column Alias</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;">Short name of the emperor in upper case (e.g., ‘AUGUSTUS‘). This is a unique name, and there should only be one entry per emperor.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">name</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Full name of the emperor in lower case (e.g., ‘tiberivs caesar divi avgvsti filivs avgvstvs‘).</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">full_name</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Birth place in format ‘City, Province’ (with a space after the comma). If the birth city is missing but the province is known, the table should read ‘Unknown, Province’, and vice versa. If both are missing the value should simply read ‘Unknown’ (i.e., instead of 'Unknown, Unknown').</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">birthplace</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Age at time of death, in years (e.g., 34). In cases where either the birth or death date are missing the value should read ‘Unknown’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">age</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Length of reign, in years (e.g., 4). Calculated as the date the reign ended minus the date the reign began. In cases where the start or end date of the reign are missing the value should read ‘Unknown’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">reign</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Cause of death. Limited to ‘Assassination‘, ‘Natural Causes‘, ‘Execution‘, ‘Died in Battle‘, and ‘Suicide‘. All other causes of death should be categorized as ‘Other‘.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">cod</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Era in which they ruled. Reigns that began prior to 284 AD should be categorized as ‘Principate‘, and reigns that began in 284 AD or later should be categorized as ‘Dominate‘.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">era</td>
# </tr>
# </tbody>
# </table>

# %%
# %%sql
# postgresql:///roman
# Out:
# 'Connected: @roman'

# %%
# %sql select * from emperors;
# Out:
#  * postgresql:///roman
# 71 rows affected.
# [('0', 'Caligula', 'GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS', '0012-08-31T00:53:28+00:53', '0041-01-24T00:53:28+00:53', 'Antitum', 'Italia', 'Birthright', '0037-03-18T00:53:28+00:53', '0041-01-24T00:53:28+00:53', 'Assassination', 'Senate', 'Julio-Claudian', 'Principate'),
#  ('1', 'Claudius', 'TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS', '0009-08-01T00:53:28+00:53', '0054-10-13T00:53:28+00:53', 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', '0041-01-25T00:53:28+00:53', '0054-10-13T00:53:28+00:53', 'Assassination', 'Wife', 'Julio-Claudian', 'Principate'),
#  ('2', 'Nero', 'NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS', '0037-12-15T00:53:28+00:53', '0068-06-09T00:53:28+00:53', 'Antitum', 'Italia', 'Birthright', '0054-10-13T00:53:28+00:53', '0068-06-09T00:53:28+00:53', 'Suicide', 'Senate', 'Julio-Claudian', 'Principate'),
#  ('3', 'Galba', 'SERVIVS SVLPICIVS GALBA CAESAR AVGVSTVS', '0002-12-24T00:53:28+00:53', '0069-01-15T00:53:28+00:53', 'Terracina', 'Italia', 'Seized Power', '0068-06-08T00:53:28+00:53', '0069-01-15T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Flavian', 'Principate'),
#  ('4', 'Otho', 'MARCVS SALVIVS OTHO CAESAR AVGVSTVS', '0032-04-28T00:53:28+00:53', '0069-04-16T00:53:28+00:53', 'Terentinum', 'Italia', 'Appointment by Praetorian Guard', '0069-01-15T00:53:28+00:53', '0069-04-16T00:53:28+00:53', 'Suicide', 'Other Emperor', 'Flavian', 'Principate'),
#  ('5', 'Vitellius', 'AVLVS VITELLIVS GERMANICVS AVGVSTVS', '0015-09-24T00:53:28+00:53', '0069-12-20T00:53:28+00:53', 'Rome', 'Italia', 'Seized Power', '0069-04-17T00:53:28+00:53', '0069-12-20T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Flavian', 'Principate'),
#  ('6', 'Vespasian', 'TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS', '0009-11-17T00:53:28+00:53', '0079-06-24T00:53:28+00:53', 'Falacrine', 'Italia', 'Seized Power', '0069-12-21T00:53:28+00:53', '0079-06-24T00:53:28+00:53', 'Natural Causes', 'Disease', 'Flavian', 'Principate'),
#  ('7', 'Titus', 'TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS', '0039-12-30T00:53:28+00:53', '0081-09-13T00:53:28+00:53', 'Rome', 'Italia', 'Birthright', '0079-06-24T00:53:28+00:53', '0081-09-13T00:53:28+00:53', 'Natural Causes', 'Disease', 'Flavian', 'Principate'),
#  ('8', 'Domitian', 'TITVS FLAVIVS CAESAR DOMITIANVS AVGVSTVS', '0051-10-24T00:53:28+00:53', '0096-09-18T00:53:28+00:53', 'Rome', 'Italia', 'Birthright', '0081-09-14T00:53:28+00:53', '0096-09-18T00:53:28+00:53', 'Assassination', 'Court Officials', 'Flavian', 'Principate'),
#  ('9', 'Nerva', 'MARCVS COCCEIVS NERVA CAESAR AVGVSTVS', '0030-11-08T00:53:28+00:53', '0098-01-27T00:53:28+00:53', 'Narni', 'Italia', 'Appointment by Senate', '0096-09-18T00:53:28+00:53', '0098-01-27T00:53:28+00:53', 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate'),
#  ('10', 'Trajan', 'CAESAR MARCVS VLPIVS NERVA TRAIANVS AVGVSTVS', '0053-09-18T00:53:28+00:53', '0117-08-07T00:53:28+00:53', 'Italica', 'Hispania Baetica', 'Birthright', '0098-01-28T00:53:28+00:53', '0117-08-07T00:53:28+00:53', 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate'),
#  ('11', 'Hadrian', 'CAESAR PVBLIVS AELIVS TRAIANVS HADRIANVS AVGVSTVS', '0076-01-24T00:53:28+00:53', '0138-07-10T00:53:28+00:53', 'Italica', 'Hispania Baetica', 'Birthright', '0117-08-11T00:53:28+00:53', '0138-07-10T00:53:28+00:53', 'Natural Causes', 'Heart Failure', 'Nerva-Antonine', 'Principate'),
#  ('12', 'Antonius Pius', 'CAESAR TITVS AELIVS HADRIANVS ANTONINVS AVGVSTVS PIVS', '0086-09-19T00:53:28+00:53', '0161-03-07T00:53:28+00:53', 'Lanuvium', 'Italia', 'Birthright', '0138-07-10T00:53:28+00:53', '0161-03-07T00:53:28+00:53', 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate'),
#  ('13', 'Marcus Aurelius', 'CAESAR MARCVS AVRELIVS ANTONINVS AVGVSTVS', '0121-04-26T00:53:28+00:53', '0180-03-17T00:53:28+00:53', 'Rome', 'Italia', 'Birthright', '0161-03-07T00:53:28+00:53', '0180-03-17T00:53:28+00:53', 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate'),
#  ('14', 'Lucius Verus', 'CAESAR LVCIVS AVRELIVS VERVS AVGVSTVS', '0130-12-15T00:53:28+00:53', '0169-03-15T00:53:28+00:53', 'Rome', 'Italia', 'Birthright', '0161-03-07T00:53:28+00:53', '0169-03-15T00:53:28+00:53', 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate'),
#  ('15', 'Commodus', 'CAESAR MARCVS AVRELIVS COMMODVS ANTONINVS AVGVSTVS', '0161-08-31T00:53:28+00:53', '0192-12-31T00:53:28+00:53', 'Lanuvium', 'Italia', 'Birthright', '0177-01-01T00:53:28+00:53', '0192-12-31T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Nerva-Antonine', 'Principate'),
#  ('16', 'Pertinax', 'CAESAR PVBLIVS HELVIVS PERTINAX AVGVSTVS', '0126-08-01T00:53:28+00:53', '0193-03-28T00:53:28+00:53', 'Alba', 'Italia', 'Appointment by Praetorian Guard', '0193-01-01T00:53:28+00:53', '0193-03-28T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Severan', 'Principate'),
#  ('17', 'Didius Julianus', 'CAESAR MARCVS DIDIVS SEVERVS IVLIANVS AVGVSTVS', '0133-01-30T00:53:28+00:53', '0193-07-01T00:53:28+00:53', 'Milan', 'Italia', 'Purchase', '0193-03-28T00:53:28+00:53', '0193-07-01T00:53:28+00:53', 'Execution', 'Senate', 'Severan', 'Principate'),
#  ('18', 'Septimus Severus', 'CAESAR LVCIVS SEPTIMIVS SEVERVS PERTINAX AVGVSTVS', '0145-04-11T00:53:28+00:53', '0211-02-04T00:53:28+00:53', 'Leptis Magna', 'Libya', 'Seized Power', '0193-04-09T00:53:28+00:53', '0211-02-04T00:53:28+00:53', 'Natural Causes', 'Disease', 'Severan', 'Principate'),
#  ('19', 'Caracalla', 'CAESAR MARCVS AVRELIVS SEVERVS ANTONINVS PIVS AVGVSTVS', '0188-04-04T00:53:28+00:53', '0217-04-08T00:53:28+00:53', 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', '0198-01-01T00:53:28+00:53', '0217-04-08T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Severan', 'Principate'),
#  ('20', 'Geta', 'CAESAR PVBLIVS SEPTIMIVS GETA AVGVSTUS', '0189-03-07T00:53:28+00:53', '0211-12-19T00:53:28+00:53', 'Rome', 'Italia', 'Birthright', '0209-01-01T00:53:28+00:53', '0211-12-26T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Severan', 'Principate'),
#  ('21', 'Macrinus', 'MARCVS OPELLIVS SEVERVS MACRINVS AVGVSTVS PIVS FELIX', '0165-01-01T00:53:28+00:53', '0218-06-08T00:53:28+00:53', 'Iol Caesarea', 'Mauretania', 'Seized Power', '0217-04-11T00:53:28+00:53', '0218-06-08T00:53:28+00:53', 'Execution', 'Other Emperor', 'Severan', 'Principate'),
#  ('22', 'Elagabalus', 'MARCVS AVRELIVS ANTONINVS AVGVSTVS', '0203-01-01T00:53:28+00:53', '0222-03-11T00:53:28+00:53', 'Emesa', 'Syria', 'Birthright', '0218-06-08T00:53:28+00:53', '0222-03-11T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Severan', 'Principate'),
#  ('23', 'Severus Alexander', 'CAESAR MARCVS AVRELIVS SEVERVS ALEXANDER AVGVSTVS', '0208-10-01T00:53:28+00:53', '0235-03-18T00:53:28+00:53', 'Arca Caesarea', 'Syria', 'Birthright', '0222-03-13T00:53:28+00:53', '0235-03-18T00:53:28+00:53', 'Assassination', 'Own Army', 'Severan', 'Principate'),
#  ('24', 'Maximinus I', 'CAESAR GAIVS IVLIVS VERVS MAXIMINVS AVGVSTVS', '0173-01-01T00:53:28+00:53', '0238-06-15T00:53:28+00:53', None, 'Thrace', 'Appointment by Praetorian Guard', '0235-03-20T00:53:28+00:53', '0238-06-15T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('25', 'Gordian I', 'CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS AFRICANVS AVGVSTVS', '0159-01-01T00:53:28+00:53', '0238-04-12T00:53:28+00:53', None, 'Phrygia', 'Appointment by Senate', '0238-03-22T00:53:28+00:53', '0238-04-12T00:53:28+00:53', 'Suicide', 'Other Emperor', 'Gordian', 'Principate'),
#  ('26', 'Gordian II', 'CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ROMANVS AFRICANVS AVGVSTVS', '0192-01-01T00:53:28+00:53', '0238-04-12T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-03-22T00:53:28+00:53', '0238-04-12T00:53:28+00:53', 'Execution', 'Other Emperor', 'Gordian', 'Principate'),
#  ('27', 'Balbinus', 'CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS AVGVSTVS', '0178-01-01T00:53:28+00:53', '0238-07-29T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-04-22T00:53:28+00:53', '0238-07-29T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('28', 'Gordian III', 'CAESAR MARCVS ANTONIVS GORDIANVS AVGVSTVS', '0225-01-20T00:53:28+00:53', '0244-02-11T00:53:28+00:53', 'Rome', 'Italia', 'Appointment by Senate', '0238-04-22T00:53:28+00:53', '0244-02-11T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate'),
#  ('29', 'Pupienus', 'CAESAR MARCVS CLODIVS PVPIENVS MAXIMVS AVGVSTVS', '0178-01-01T00:53:28+00:53', '0238-07-29T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-04-22T00:53:28+00:53', '0238-07-29T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('30', 'Philip I', 'CAESAR MARCVS IVLIVS PHILIPPVS AVGVSTVS', '0204-01-01T00:53:28+00:53', '0249-10-01T00:53:28+00:53', 'Shahba', 'Syria', 'Seized Power', '0244-02-14T00:53:28+00:53', '0249-10-01T00:53:28+00:53', 'Execution', 'Other Emperor', 'Gordian', 'Principate'),
#  ('31', 'Trajan Decius', 'CAESAR GAIVS MESSIVS QVINTVS TRAIANVS DECIVS AVGVSTVS', '0201-01-01T00:53:28+00:53', '0251-06-15T00:53:28+00:53', 'Budalia', 'Pannonia Inferior', 'Appointment by Army', '0249-10-01T00:53:28+00:53', '0251-06-15T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate'),
#  ('32', 'Trebonianus Gallus', 'CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS', '0206-01-01T00:53:28+00:53', '0253-08-15T00:53:28+00:53', None, 'Italia', 'Appointment by Army', '0251-06-15T00:53:28+00:53', '0253-08-15T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Gordian', 'Principate'),
#  ('33', 'Hostilian', 'CAESAR CAIVS VALENS HOSTILIANVS MESSIVS QVINTVS AVGVSTVS', '0230-01-01T00:53:28+00:53', '0251-10-01T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Birthright', '0251-06-15T00:53:28+00:53', '0251-10-01T00:53:28+00:53', 'Natural Causes', 'Disease', 'Gordian', 'Principate'),
#  ('34', 'Aemilian', 'CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS', '0207-01-01T00:53:28+00:53', '0253-10-15T00:53:28+00:53', None, 'Africa', 'Appointment by Army', '0253-08-15T00:53:28+00:53', '0253-10-15T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Gordian', 'Principate'),
#  ('35', 'Valerian', 'CAESAR PVBLIVS LICINIVS VALERIANVS AVGVSTVS', '0195-01-01T00:53:28+00:53', '0264-01-01T00:53:28+00:53', None, None, 'Appointment by Army', '0253-10-15T00:53:28+00:53', '0260-01-01T00:53:28+00:53', 'Captivity', 'Opposing Army', 'Gordian', 'Principate'),
#  ('36', 'Gallienus', 'CAESAR PVBLIVS LICINIVS EGNATIVS GALLIENVS AVGVSTVS', '0218-01-01T00:53:28+00:53', '0268-09-15T00:53:28+00:53', None, None, 'Birthright', '0253-10-15T00:53:28+00:53', '0268-09-15T00:53:28+00:53', 'Assassination', 'Own Army', 'Gordian', 'Principate'),
#  ('37', 'Claudius Gothicus', 'CAESAR MARCVS AVRELIVS CLAVDIVS AVGVSTVS', '0213-05-10T00:53:28+00:53', '0270-01-15T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Seized Power', '0268-09-15T00:53:28+00:53', '0270-01-15T00:53:28+00:53', 'Natural Causes', 'Disease', 'Gordian', 'Principate'),
#  ('38', 'Quintillus', 'CAESAR MARCVS AVRELIVS CLAVDIVS QVINTILLVS AVGVSTVS', '0212-01-01T00:53:28+00:53', '0270-04-15T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Birthright', '0270-01-15T00:53:28+00:53', '0270-04-15T00:53:28+00:53', 'Unknown', 'Unknown', 'Gordian', 'Principate'),
#  ('39', 'Aurelian', 'CAESAR LVCIVS DOMITIVS AVRELIANVS AVGVSTVS', '0214-09-09T00:53:28+00:53', '0275-09-15T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Appointment by Army', '0270-09-15T00:53:28+00:53', '0275-09-15T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('40', 'Tacitus', 'CAESAR MARCVS CLAVDIVS\xa0TACITVS AVGVSTVS', '0200-01-01T00:53:28+00:53', '0276-06-15T00:53:28+00:53', 'Interamna Nahars', 'Italia', 'Appointment by Senate', '0275-09-25T00:53:28+00:53', '0276-06-15T00:53:28+00:53', 'Natural Causes', 'Disease', 'Gordian', 'Principate'),
#  ('41', 'Florian', 'CAESAR MARCVS ANNIVS FLORIANVS AVGVSTVS', None, '0276-09-15T00:53:28+00:53', None, None, 'Birthright', '0276-06-15T00:53:28+00:53', '0276-09-15T00:53:28+00:53', 'Assassination', 'Own Army', 'Gordian', 'Principate'),
#  ('42', 'Probus', 'CAESAR MARCVS AVRELIVS PROBVS AVGVSTVS', '0232-08-19T00:53:28+00:53', '0282-10-01T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Appointment by Army', '0276-09-15T00:53:28+00:53', '0282-10-01T00:53:28+00:53', 'Assassination', 'Own Army', 'Gordian', 'Principate'),
#  ('43', 'Carus', 'CAESAR MARCVS AVRELIVS CARVS AVGVSTVS', '0230-01-01T00:53:28+00:53', '0283-08-01T00:53:28+00:53', 'Narbo', 'Gallia Narbonensis', 'Seized Power', '0282-10-01T00:53:28+00:53', '0283-08-01T00:53:28+00:53', 'Natural Causes', 'Lightning', 'Gordian', 'Principate'),
#  ('44', 'Carinus', 'CAESAR MARCVS AVRELIVS CARINVS AVGVSTVS', None, '0285-08-01T00:53:28+00:53', None, None, 'Birthright', '0283-08-01T00:53:28+00:53', '0285-08-01T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate'),
#  ('45', 'Numerian', 'CAESAR MARCVS AVRELIVS NVMERIVS NVMERIANVS AVGVSTVS', None, '0284-11-20T00:53:28+00:53', None, None, 'Birthright', '0283-08-01T00:53:28+00:53', '0284-11-20T00:53:28+00:53', 'Unknown', 'Unknown', 'Gordian', 'Principate'),
#  ('46', 'Diocletian', 'CAESAR GAIVS AVRELIVS VALERIVS DIOCLETIANVS AVGVSTVS', '0244-12-22T00:53:28+00:53', '0311-12-03T00:53:28+00:53', 'Salona', 'Dalmatian', 'Seized Power', '0284-11-20T00:53:28+00:53', '0305-05-01T00:53:28+00:53', 'Natural Causes', 'Disease', 'Constantinian', 'Dominate'),
#  ('47', 'Maximian', 'CAESAR MARCVS AVRELIVS VALERIVS MAXIMIANVS AVGVSTVS', '0250-01-01T00:53:28+00:53', '0310-07-15T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Appointment by Emperor', '0286-04-01T00:53:28+00:53', '0305-05-01T00:53:28+00:53', 'Suicide', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('48', 'Severus II', 'FLAVIVS VALERIVS SEVERVS AVGVSTVS', None, '0307-09-16T00:53:28+00:53', None, None, 'Appointment by Emperor', '0305-05-01T00:53:28+00:53', '0307-09-16T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('49', 'Galerius', 'CAESAR GALERIVS VALERIVS MAXIMIANVS AVGVSTVS', '0260-01-01T00:53:28+00:53', '0311-05-01T00:53:28+00:53', 'Romuliana', 'Moesia Superior', 'Appointment by Emperor', '0305-05-01T00:53:28+00:53', '0311-05-01T00:53:28+00:53', 'Natural Causes', 'Disease', 'Constantinian', 'Dominate'),
#  ('50', 'Constantius I', 'CAESAR GAIVS FLAVIVS VALERIVS CONSTANTIVS AVGVSTVS', '0250-03-31T00:53:28+00:53', '0306-07-25T00:53:28+00:53', 'Dardania', 'Moesia', 'Appointment by Emperor', '0305-05-01T00:53:28+00:53', '0306-07-25T00:53:28+00:53', 'Natural Causes', 'Unknown', 'Constantinian', 'Dominate'),
#  ('51', 'Constantine the Great', 'CAESAR FLAVIVS VALERIVS AVRELIVS CONSTANTINVS AVGVSTVS', '0272-02-27T00:53:28+00:53', '0337-05-22T00:53:28+00:53', 'Naissus', 'Moesia Superior', 'Birthright', '0306-07-25T00:53:28+00:53', '0337-05-22T00:53:28+00:53', 'Natural Causes', 'Disease', 'Constantinian', 'Dominate'),
#  ('52', 'Maxentius', 'MARCVS AVRELIVS VALERIVS MAXENTIVS AVGVSTVS', '0278-01-01T00:53:28+00:53', '0312-10-08T00:53:28+00:53', None, None, 'Birthright', '0306-10-08T00:53:28+00:53', '0312-10-08T00:53:28+00:53', 'Execution', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('53', 'Lucinius I', 'CAESAR GAIVS VALERIVS LICINIVS AVGVSTVS', '0250-01-01T00:53:28+00:53', '0325-03-01T00:53:28+00:53', 'Felix Romuliana', 'Moesia Superior', 'Birthright', '0308-11-11T00:53:28+00:53', '0324-09-18T00:53:28+00:53', 'Execution', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('54', 'Maximinus II', 'CAESAR GALERIVS VALERIVS MAXIMINVS AVGVSTVS', '0270-11-20T00:53:28+00:53', '0313-08-01T00:53:28+00:53', None, 'Dacia Aureliana', 'Birthright', '0311-05-01T00:53:28+00:53', '0313-08-01T00:53:28+00:53', 'Execution', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('55', 'Constantine II', 'CAESAR FLAVIVS CLAVDIVS CONSTANTINVS AVGVSTVS', '0316-02-01T00:53:28+00:53', '0340-01-01T00:53:28+00:53', 'Arelate', 'Gallia Narbonensis', 'Birthright', '0337-05-22T00:53:28+00:53', '0340-01-01T00:53:28+00:53', 'Execution', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('56', 'Constans', 'CAESAR FLAVIVS IVLIVS CONSTANS AVGVSTVS', '0320-01-01T00:53:28+00:53', '0350-02-14T00:53:28+00:53', None, 'Moesia', 'Birthright', '0337-05-22T00:53:28+00:53', '0350-02-14T00:53:28+00:53', 'Assassination', 'Usurper', 'Constantinian', 'Dominate'),
#  ('57', 'Consantius II', 'CAESAR FLAVIVS IVLIVS CONSTANTIVS AVGVSTVS', '0317-08-07T00:53:28+00:53', '0361-11-03T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Birthright', '0337-05-22T00:53:28+00:53', '0361-11-03T00:53:28+00:53', 'Natural Causes', 'Disease', 'Constantinian', 'Dominate'),
#  ('58', 'Vetranio', 'CAESAR FLAVIVS VETRANIO AVGVSTVS', None, '0356-01-01T00:53:28+00:53', None, 'Moesia', 'Seized Power', '0350-03-01T00:53:28+00:53', '0350-12-25T00:53:28+00:53', 'Unknown', 'Unknown', 'Constantinian', 'Dominate'),
#  ('59', 'Julian', 'CAESAR FLAVIVS CLAVDIVS IVLIANVS AVGVSTVS', '0331-07-01T00:53:28+00:53', '0363-06-26T00:53:28+00:53', 'Constantinople', 'Thrace', 'Birthright', '0360-02-14T00:53:28+00:53', '0363-06-26T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Constantinian', 'Dominate'),
#  ('60', 'Jovian', 'CAESAR FLAVIVS IOVIANVS AVGVSTVS', '0331-01-01T00:53:28+00:53', '0364-02-17T00:53:28+00:53', 'Singidunum', 'Moesia', 'Appointment by Army', '0363-06-26T00:53:28+00:53', '0364-02-17T00:53:28+00:53', 'Natural Causes', 'Fire', 'Constantinian', 'Dominate'),
#  ('61', 'Valentinian I', 'FLAVIVS VALENTINIANVS AVGVSTVS', '0321-07-03T00:53:28+00:53', '0375-11-17T00:53:28+00:53', 'Cibalae', 'Pannonia', 'Election', '0364-02-26T00:53:28+00:53', '0375-11-17T00:53:28+00:53', 'Natural Causes', 'Aneurism', 'Valentinian', 'Dominate'),
#  ('62', 'Valens', 'FLAVIVS IVLIVS VALENS AVGVSTVS', '0328-01-01T00:53:28+00:53', '0378-08-09T00:53:28+00:53', 'Cibalae', 'Pannonia', 'Birthright', '0364-03-28T00:53:28+00:53', '0378-08-09T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate'),
#  ('63', 'Gratian', 'FLAVIVS GRATIANVS AVGVSTVS', '0359-04-18T00:53:28+00:53', '0383-08-25T00:53:28+00:53', 'Sirmium', 'Pannonia', 'Birthright', '0367-08-04T00:53:28+00:53', '0383-08-25T00:53:28+00:53', 'Assassination', 'Own Army', 'Valentinian', 'Dominate'),
#  ('64', 'Valentinian II', 'FLAVIVS VALENTINIANVS INVICTVS AVGVSTVS', '0371-01-01T00:53:28+00:53', '0392-05-15T00:53:28+00:53', 'Milan', 'Italia', 'Birthright', '0375-11-17T00:53:28+00:53', '0392-05-15T00:53:28+00:53', 'Suicide', 'Unknown', 'Valentinian', 'Dominate'),
#  ('65', 'Theodosius I', 'FLAVIVS THEODOSIVS AVGVSTVS', '0347-01-11T00:53:28+00:53', '0395-01-17T00:53:28+00:53', 'Cauca', 'Hispania', 'Birthright', '0379-01-01T00:53:28+00:53', '0395-01-17T00:53:28+00:53', 'Natural Causes', 'Disease', 'Theodosian', 'Dominate'),
#  ('66', 'Maximinus II', 'CAESAR GALERIVS VALERIVS MAXIMINVS AVGVSTVS', '0270-11-20T00:53:28+00:53', '0313-08-01T00:53:28+00:53', None, 'Dacia Aureliana', 'Birthright', '0311-05-01T00:53:28+00:53', '0313-08-01T00:53:28+00:53', 'Execution', 'Other Emperor', 'Constantinian', 'Dominate'),
#  ('67', 'Valens', 'FLAVIVS IVLIVS VALENS AVGVSTVS', '0328-01-01T00:53:28+00:53', '0378-08-09T00:53:28+00:53', 'Cibalae', 'Pannonia', 'Birthright', '0364-03-28T00:53:28+00:53', '0378-08-09T00:53:28+00:53', 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate'),
#  ('68', 'Caligula', 'GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS', '0012-08-31T00:53:28+00:53', '0041-01-24T00:53:28+00:53', 'Antitum', 'Italia', 'Birthright', '0037-03-18T00:53:28+00:53', '0041-01-24T00:53:28+00:53', 'Assassination', 'Senate', 'Julio-Claudian', 'Principate'),
#  ('69', 'Numerian', 'CAESAR MARCVS AVRELIVS NVMERIVS NVMERIANVS AVGVSTVS', None, '0284-11-20T00:53:28+00:53', None, None, 'Birthright', '0283-08-01T00:53:28+00:53', '0284-11-20T00:53:28+00:53', 'Unknown', 'Unknown', 'Gordian', 'Principate'),
#  ('70', 'Vitellius', 'AVLVS VITELLIVS GERMANICVS AVGVSTVS', '0015-09-24T00:53:28+00:53', '0069-12-20T00:53:28+00:53', 'Rome', 'Italia', 'Seized Power', '0069-04-17T00:53:28+00:53', '0069-12-20T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Flavian', 'Principate')]

# %%
# %sql select upper(name) as name, lower(full_name) as full_name from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs')]

# %%
# %sql select * from emperors where birth_city is null limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('24', 'Maximinus I', 'CAESAR GAIVS IVLIVS VERVS MAXIMINVS AVGVSTVS', '0173-01-01T00:53:28+00:53', '0238-06-15T00:53:28+00:53', None, 'Thrace', 'Appointment by Praetorian Guard', '0235-03-20T00:53:28+00:53', '0238-06-15T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('25', 'Gordian I', 'CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS AFRICANVS AVGVSTVS', '0159-01-01T00:53:28+00:53', '0238-04-12T00:53:28+00:53', None, 'Phrygia', 'Appointment by Senate', '0238-03-22T00:53:28+00:53', '0238-04-12T00:53:28+00:53', 'Suicide', 'Other Emperor', 'Gordian', 'Principate'),
#  ('26', 'Gordian II', 'CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ROMANVS AFRICANVS AVGVSTVS', '0192-01-01T00:53:28+00:53', '0238-04-12T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-03-22T00:53:28+00:53', '0238-04-12T00:53:28+00:53', 'Execution', 'Other Emperor', 'Gordian', 'Principate'),
#  ('27', 'Balbinus', 'CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS AVGVSTVS', '0178-01-01T00:53:28+00:53', '0238-07-29T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-04-22T00:53:28+00:53', '0238-07-29T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('29', 'Pupienus', 'CAESAR MARCVS CLODIVS PVPIENVS MAXIMVS AVGVSTVS', '0178-01-01T00:53:28+00:53', '0238-07-29T00:53:28+00:53', None, None, 'Appointment by Senate', '0238-04-22T00:53:28+00:53', '0238-07-29T00:53:28+00:53', 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate'),
#  ('32', 'Trebonianus Gallus', 'CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS', '0206-01-01T00:53:28+00:53', '0253-08-15T00:53:28+00:53', None, 'Italia', 'Appointment by Army', '0251-06-15T00:53:28+00:53', '0253-08-15T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Gordian', 'Principate'),
#  ('34', 'Aemilian', 'CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS', '0207-01-01T00:53:28+00:53', '0253-10-15T00:53:28+00:53', None, 'Africa', 'Appointment by Army', '0253-08-15T00:53:28+00:53', '0253-10-15T00:53:28+00:53', 'Assassination', 'Other Emperor', 'Gordian', 'Principate'),
#  ('35', 'Valerian', 'CAESAR PVBLIVS LICINIVS VALERIANVS AVGVSTVS', '0195-01-01T00:53:28+00:53', '0264-01-01T00:53:28+00:53', None, None, 'Appointment by Army', '0253-10-15T00:53:28+00:53', '0260-01-01T00:53:28+00:53', 'Captivity', 'Opposing Army', 'Gordian', 'Principate'),
#  ('36', 'Gallienus', 'CAESAR PVBLIVS LICINIVS EGNATIVS GALLIENVS AVGVSTVS', '0218-01-01T00:53:28+00:53', '0268-09-15T00:53:28+00:53', None, None, 'Birthright', '0253-10-15T00:53:28+00:53', '0268-09-15T00:53:28+00:53', 'Assassination', 'Own Army', 'Gordian', 'Principate'),
#  ('41', 'Florian', 'CAESAR MARCVS ANNIVS FLORIANVS AVGVSTVS', None, '0276-09-15T00:53:28+00:53', None, None, 'Birthright', '0276-06-15T00:53:28+00:53', '0276-09-15T00:53:28+00:53', 'Assassination', 'Own Army', 'Gordian', 'Principate')]

# %%
# %sql SELECT upper(name) as name, lower(full_name) as full_name, CASE WHEN birth_city is null and birth_province is null THEN 'Unknown' WHEN birth_city is null THEN 'Unknown, ' || birth_province WHEN birth_province is null THEN birth_city || ', Unknown' ELSE birth_city || ', ' || birth_province END AS birthplace FROM emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', 'Antitum, Italia'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', 'Lugdunum, Gallia Lugdunensis'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs', 'Antitum, Italia'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs', 'Terracina, Italia'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs', 'Terentinum, Italia'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', 'Rome, Italia'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', 'Falacrine, Italia'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', 'Rome, Italia'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', 'Rome, Italia'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs', 'Narni, Italia')]

# %%
# %sql select birth from emperors where birth is null limit 10;
# Out:
#  * postgresql:///roman
# 6 rows affected.
# [(None,), (None,), (None,), (None,), (None,), (None,)]

# %%
# %sql select substring(birth from 1 for 10) from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('0012-08-31',),
#  ('0009-08-01',),
#  ('0037-12-15',),
#  ('0002-12-24',),
#  ('0032-04-28',),
#  ('0015-09-24',),
#  ('0009-11-17',),
#  ('0039-12-30',),
#  ('0051-10-24',),
#  ('0030-11-08',)]

# %%
# %sql select substring(death from 1 for 10) from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('0041-01-24',),
#  ('0054-10-13',),
#  ('0068-06-09',),
#  ('0069-01-15',),
#  ('0069-04-16',),
#  ('0069-12-20',),
#  ('0079-06-24',),
#  ('0081-09-13',),
#  ('0096-09-18',),
#  ('0098-01-27',)]

# %%
# %sql SELECT (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text AS age from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('29',),
#  ('45',),
#  ('31',),
#  ('67',),
#  ('37',),
#  ('54',),
#  ('70',),
#  ('42',),
#  ('45',),
#  ('68',)]

# %%
# %sql SELECT CASE WHEN birth is null OR death is null THEN 'Unknown' ELSE (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text END AS age from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('29',),
#  ('45',),
#  ('31',),
#  ('67',),
#  ('37',),
#  ('54',),
#  ('70',),
#  ('42',),
#  ('45',),
#  ('68',)]

# %%
# %sql SELECT upper(name) as name, lower(full_name) as full_name, CASE WHEN birth_city is null and birth_province is null THEN 'Unknown' WHEN birth_city is null THEN 'Unknown, ' || birth_province WHEN birth_province is null THEN birth_city || ', Unknown' ELSE birth_city || ', ' || birth_province END AS birthplace, CASE WHEN birth is null OR death is null THEN 'Unknown' ELSE (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text END AS age FROM emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', 'Antitum, Italia', '29'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', 'Lugdunum, Gallia Lugdunensis', '45'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs', 'Antitum, Italia', '31'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs', 'Terracina, Italia', '67'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs', 'Terentinum, Italia', '37'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', 'Rome, Italia', '54'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', 'Falacrine, Italia', '70'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', 'Rome, Italia', '42'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', 'Rome, Italia', '45'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs', 'Narni, Italia', '68')]

# %%
# %sql SELECT CASE WHEN reign_start is null OR reign_end is null THEN 'Unknown' ELSE (DATE_PART('year', substring(reign_end from 1 for 10)::date) - DATE_PART('year', substring(reign_start from 1 for 10)::date))::text END AS reign from emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('4',),
#  ('13',),
#  ('14',),
#  ('1',),
#  ('0',),
#  ('0',),
#  ('10',),
#  ('2',),
#  ('15',),
#  ('2',)]

# %%
# %sql SELECT upper(name) as name, lower(full_name) as full_name, CASE WHEN birth_city is null and birth_province is null THEN 'Unknown' WHEN birth_city is null THEN 'Unknown, ' || birth_province WHEN birth_province is null THEN birth_city || ', Unknown' ELSE birth_city || ', ' || birth_province END AS birthplace, CASE WHEN birth is null OR death is null THEN 'Unknown' ELSE (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text END AS age, CASE WHEN reign_start is null OR reign_end is null THEN 'Unknown' ELSE (DATE_PART('year', substring(reign_end from 1 for 10)::date) - DATE_PART('year', substring(reign_start from 1 for 10)::date))::text END AS reign FROM emperors limit 10;
# Out:
#  * postgresql:///roman
# 10 rows affected.
# [('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', 'Antitum, Italia', '29', '4'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', 'Lugdunum, Gallia Lugdunensis', '45', '13'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs', 'Antitum, Italia', '31', '14'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs', 'Terracina, Italia', '67', '1'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs', 'Terentinum, Italia', '37', '0'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', 'Rome, Italia', '54', '0'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', 'Falacrine, Italia', '70', '10'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', 'Rome, Italia', '42', '2'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', 'Rome, Italia', '45', '15'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs', 'Narni, Italia', '68', '2')]

# %%
# %sql select case when cause not in ('Assassination', 'Natural Causes', 'Execution', 'Died in Battle', 'Suicide') THEN 'Other' ELSE cause END AS cod from emperors;
# Out:
#  * postgresql:///roman
# 71 rows affected.
# [('Assassination',),
#  ('Assassination',),
#  ('Suicide',),
#  ('Assassination',),
#  ('Suicide',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Assassination',),
#  ('Assassination',),
#  ('Execution',),
#  ('Natural Causes',),
#  ('Assassination',),
#  ('Assassination',),
#  ('Execution',),
#  ('Assassination',),
#  ('Assassination',),
#  ('Assassination',),
#  ('Suicide',),
#  ('Execution',),
#  ('Assassination',),
#  ('Died in Battle',),
#  ('Assassination',),
#  ('Execution',),
#  ('Died in Battle',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Assassination',),
#  ('Other',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Other',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Assassination',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Died in Battle',),
#  ('Other',),
#  ('Natural Causes',),
#  ('Suicide',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Execution',),
#  ('Execution',),
#  ('Execution',),
#  ('Execution',),
#  ('Assassination',),
#  ('Natural Causes',),
#  ('Other',),
#  ('Died in Battle',),
#  ('Natural Causes',),
#  ('Natural Causes',),
#  ('Died in Battle',),
#  ('Assassination',),
#  ('Suicide',),
#  ('Natural Causes',),
#  ('Execution',),
#  ('Died in Battle',),
#  ('Assassination',),
#  ('Other',),
#  ('Assassination',)]

# %%
# %sql SELECT upper(name) as name, lower(full_name) as full_name, CASE WHEN birth_city is null and birth_province is null THEN 'Unknown' WHEN birth_city is null THEN 'Unknown, ' || birth_province WHEN birth_province is null THEN birth_city || ', Unknown' ELSE birth_city || ', ' || birth_province END AS birthplace, CASE WHEN birth is null OR death is null THEN 'Unknown' ELSE (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text END AS age, CASE WHEN reign_start is null OR reign_end is null THEN 'Unknown' ELSE (DATE_PART('year', substring(reign_end from 1 for 10)::date) - DATE_PART('year', substring(reign_start from 1 for 10)::date))::text END AS reign, case when cause not in ('Assassination', 'Natural Causes', 'Execution', 'Died in Battle', 'Suicide') THEN 'Other' ELSE cause END AS cod, era FROM emperors ORDER BY name ASC;

# %%
# %sql SELECT DISTINCT(UPPER(name)), era FROM emperors;

# %%
# %sql SELECT DISTINCT(upper(name)) as name, lower(full_name) as full_name, CASE WHEN birth_city is null and birth_province is null THEN 'Unknown' WHEN birth_city is null THEN 'Unknown, ' || birth_province WHEN birth_province is null THEN birth_city || ', Unknown' ELSE birth_city || ', ' || birth_province END AS birthplace, CASE WHEN birth is null OR death is null THEN 'Unknown' ELSE (DATE_PART('year', substring(death from 1 for 10)::date) - DATE_PART('year', substring(birth from 1 for 10)::date))::text END AS age, CASE WHEN reign_start is null OR reign_end is null THEN 'Unknown' ELSE (DATE_PART('year', substring(reign_end from 1 for 10)::date) - DATE_PART('year', substring(reign_start from 1 for 10)::date))::text END AS reign, case when cause not in ('Assassination', 'Natural Causes', 'Execution', 'Died in Battle', 'Suicide') THEN 'Other' ELSE cause END AS cod, era FROM emperors ORDER BY name ASC;
